# %% [markdown]
# ## Registered Retailers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Registered Retailers 2021'] = merged['Registered Retailers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Registered Retailers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Registered Retailers 2021',cmap='YlOrRd', vmax = 50, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Registered Retailers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Registered Retailers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.1),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Registered Retailers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Registered Retailers 2022'] = merged['Registered Retailers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Registered Retailers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Registered Retailers 2022',cmap='YlOrRd', vmax = 50, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Registered Retailers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Registered Retailers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Active Retailers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Active Retailers 2021'] = merged['Active Retailers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Active Retailers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Active Retailers 2021',cmap='YlOrRd', vmax = 50, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Active Retailers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Active Retailers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Active Retailers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Active Retailers 2022'] = merged['Active Retailers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Active Retailers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Active Retailers 2022',cmap='YlOrRd', vmax = 50, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Active Retailers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Active Retailers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Transacted Retailers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Transacted Retailers 2021'] = merged['Transacted Retailers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Transacted Retailers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Transacted Retailers 2021',cmap='YlOrRd', vmax = 25, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Transacted Retailers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Transacted Retailers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Transacted Retailers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df.head()

df = pd.read_csv('philippines_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM2_EN').join(df.set_index('Province'))
merged['Transacted Retailers 2022'] = merged['Transacted Retailers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Aklan': 'AKL','Batangas': 'BTG','Benguet': 'BEN',
    'Bukidnon': 'BUK','Bulacan': 'BUL','Cagayan': 'CAG','Camarines Sur': 'CAS',
    'Cebu': 'CEB','Compostela Valley': 'COM','Cotabato (North Cotabato)': 'NCO','Davao Del Norte': 'DAV',
    'Davao Del Sur': 'DAS','Ilocos Norte': 'ILN','Isabela': 'ISA','La Union': 'LUN','Laguna': 'LAG','Lanao Del Sur': 'LAS',
    'Leyte': 'LEY','Misamis Oriental': 'MSR','Negros Occidental': 'NEC','Nueva Ecija': 'NUE','Nueva Vizcaya': 'NUV','Occidental Mindoro': 'MDC',
    'Oriental Mindoro': 'MDR','Pampanga': 'PAM', 'Pangasinan': 'PAN','Quezon': 'QUE','Quirino': 'QUI','South Cotabato': 'SCO',
    'Sultan Kudarat': 'SUK','Tarlac': 'TAR','Zambales': 'ZMB'
}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM2_EN'] = map_df_copy['ADM2_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Transacted Retailers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Transacted Retailers 2022',cmap='YlOrRd', vmax = 25, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Transacted Retailers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Transacted Retailers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM2_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM2_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Registered Farmers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Registered Farmers 2021'] = merged['Registered Farmers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Registered Farmers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Registered Farmers 2021',cmap='YlOrRd', vmax = 16000, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Registered Farmers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Registered Farmers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Registered Farmers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Registered Farmers 2022'] = merged['Registered Farmers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Registered Farmers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Registered Farmers 2022',cmap='YlOrRd', vmax = 16000, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Registered Farmers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Registered Farmers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Active Farmers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Active Farmers 2021'] = merged['Active Farmers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Active Farmers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Active Farmers 2021',cmap='YlOrRd', vmax = 16000, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Active Farmers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Active Farmers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Active Farmers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Active Farmers 2022'] = merged['Active Farmers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Active Farmers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Active Farmers 2022',cmap='YlOrRd', vmax = 16000, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Active Farmers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Active Farmers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Transacted Farmers 2021

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Transacted Farmers 2021'] = merged['Transacted Farmers 2021'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Transacted Farmers 2021', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Transacted Farmers 2021',cmap='YlOrRd', vmax = 750, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Transacted Farmers 2021'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Transacted Farmers 2021'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## Transacted Farmers 2022

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'tanzania-counties\tza_admbnda_adm1_20181019.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('tanzania_heatmap.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('ADM1_EN').join(df.set_index('Region'))
merged['Transacted Farmers 2022'] = merged['Transacted Farmers 2022'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {'Arusha': 'ARU', 'Dar-es-salaam': 'DAR', 'Dodoma': 'DOD', 'Geita': 'GEI', 'Iringa': 'IRI', 
              'Kagera': 'KAG', 'Kaskazini Pemba': 'KPE', 'Kaskazini Unjuga': 'KUN', 'Katavi': 'KAT', 'Kigoma': 'KIG', 
              'Kilimanjaro': 'KIL', 'Kusini Pemba': 'KUP', 'Kusini Unguja': 'KUN', 'Lindi': 'LIN', 'Manyara': 'MAN', 
              'Mara': 'MAR', 'Mbeya': 'MBE', 'Mjini Magharibi': 'MJI', 'Morogoro': 'MOR', 'Mtwara': 'MTW', 'Mwanza': 
              'MWA', 'Njombe': 'NJM', 'Pwani': 'PWA', 'Rukwa': 'RUK', 'Ruvuma': 'RUV', 'Shinyanga': 'SHI', 'Simiyu': 
              'SIM', 'Singida': 'SIN', 'Songwe': 'SON', 'Tabora': 'TAB', 'Tanga': 'TAN'}

# Replace full state names with abbreviations in map_df_copy
map_df_copy['ADM1_EN'] = map_df_copy['ADM1_EN'].replace(state_abbr)

#Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('Transacted Farmers 2022', fontdict={'fontsize': '20', 'fontweight' : '10'})
# Plot the figure
merged.plot(column='Transacted Farmers 2022',cmap='YlOrRd', vmax = 750, linewidth=0.8, ax=ax, edgecolor='0',legend=True,markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['Transacted Farmers 2022'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['Transacted Farmers 2022'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.2),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['ADM1_EN'] in state_abbr.values():
        txt = plt.annotate(text=row['ADM1_EN'], xy=row['geometry'].centroid.coords[0], horizontalalignment='center', fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# %% [markdown]
# ## No retailers

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'kenyan-counties\County.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
map_df.head()

df = pd.read_csv('no_retailers.csv')
pd.set_option('display.max_columns', None)

#Merging the data
merged = map_df.set_index('COUNTY').join(df.set_index('county'))
merged['no_retailers'] = merged['no_retailers'].replace(np.nan, 0)
merged.head()

# Create dictionary of state abbreviations
state_abbr = {
    'Baringo': 'BAR', 'Bomet': 'BOM', 'Bungoma': 'BUN', 'Busia': 'BUS', 'Keiyo-Marakwet': 'EMK', 'Embu': 'EMB',
    'Garissa': 'GAR', 'Homa Bay': 'HOB', 'Isiolo': 'ISI', 'Kajiado': 'KAJ', 'Kakamega': 'KAK', 'Kericho': 'KER',
    'Kiambu': 'KIA', 'Kilifi': 'KIL', 'Kirinyaga': 'KIR', 'Kisii': 'KIS', 'Kisumu': 'KSM', 'Kitui': 'KIT', 'Kwale': 'KWA',
    'Laikipia': 'LAI', 'Lamu': 'LAM', 'Machakos': 'MAC', 'Makueni': 'MAK', 'Mandera': 'MAN', 'Marsabit': 'MAR',
    'Meru': 'MER', 'Migori': 'MIG', 'Mombasa': 'MOM', "Murang'a": 'MUR', 'Nairobi': 'NAI', 'Nakuru': 'NAK', 'Nandi': 'NAN',
    'Narok': 'NAR', 'Nyamira': 'NYA', 'Nyandarua': 'NYD', 'Nyeri': 'NYE', 'Samburu': 'SAM', 'Siaya': 'SIA',
    'Taita Taveta': 'TTA', 'Tana River': 'TAR', 'Tharaka': 'THA', 'Trans Nzoia': 'TRN', 'Turkana': 'TUR',
    'Uasin Gishu': 'UAS', 'Vihiga': 'VIH', 'Wajir': 'WAJ', 'West Pokot': 'WPK'
}


# Replace full state names with abbreviations in map_df_copy
map_df_copy['COUNTY'] = map_df_copy['COUNTY'].replace(state_abbr)

# Create figure and axes for Matplotlib and set the title
fig, ax = plt.subplots(1, figsize=(16, 16))
ax.axis('off')
ax.set_title('No Retailers', fontdict={'fontsize': '20', 'fontweight' : '10'})

# Plot the choropleth map
merged.plot(column='no_retailers', cmap='YlOrRd', vmax=500, linewidth=0.8, ax=ax, edgecolor='0', legend=True, markersize=[39.739192, -104.990337], legend_kwds={'label': "Count"})

# Add state labels to the plot with a drop shadow effect
for idx, row in map_df_copy.iterrows():
    if row['COUNTY'] in state_abbr.values():
        txt = plt.annotate(text=row['COUNTY'],
                           xy=row['geometry'].centroid.coords[0],
                           horizontalalignment='center',
                           fontsize=8)
        txt.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])

# Add county values to the plot
for idx, row in merged.iterrows():
    if row['no_retailers'] > 0:
        # Add white drop shadow
        text = plt.annotate(text=str(int(row['no_retailers'])),
                            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y - 0.1),
                            horizontalalignment='center',
                            fontsize=8,
                            color='black')
        text.set_path_effects([patheffects.withStroke(linewidth=3, foreground='white')])  # Add white drop shadow


# Adjust the layout to prevent overlapping of elements
plt.tight_layout()
# Show the plot
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shapely as shp
from matplotlib import patheffects

from shapely.geometry import Point
sns.set_style('whitegrid')

fp = r'philippines-provinces/phl_admbnda_adm2_psa_namria_20200529.shp'
map_df = gpd.read_file(fp) 
map_df_copy = gpd.read_file(fp)
print(map_df)
# Out:
#     Shape_Leng  Shape_Area              ADM2_EN   ADM2_PCODE ADM2_REF  \
# 0     2.640967    0.334223                 Abra  PH140100000     None
# 1     3.674955    0.220065     Agusan del Norte  PH160200000     None
# 2     5.222636    0.693968       Agusan del Sur  PH160300000     None
# 3     4.626091    0.139664                Aklan  PH060400000     None
# 4     6.507665    0.205939                Albay  PH050500000     None
# ..         ...         ...                  ...          ...      ...
# 82   15.971439    0.094186            Tawi-Tawi  PH157000000     None
# 83    5.329770    0.313705             Zambales  PH037100000     None
# 84    8.170921    0.515482  Zamboanga del Norte  PH097200000     None
# 85   11.811347    0.439807    Zamboanga del Sur  PH097300000     None
# 86    8.997252    0.223408    Zamboanga Sibugay  PH098300000     None
#
#    ADM2ALT1EN ADM2ALT2EN                                          ADM1_EN  \
# ...
